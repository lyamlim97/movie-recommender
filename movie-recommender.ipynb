# %% [markdown]
# # **Movie Recommender System**

# %%
# imports
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_movies = pd.read_csv('data/ml-25m/movies.csv')
df_ratings = pd.read_csv('data/ml-25m/ratings.csv')
df_tags = pd.read_csv('data/ml-25m/tags.csv')
df_links = pd.read_csv('data/ml-25m/links.csv')
df_movies_metadata = pd.read_csv('data/movies-metadata.csv')
df_credits = pd.read_csv('data/credits.csv')
df_keywords = pd.read_csv('data/keywords.csv')

# %%
df_movies_metadata.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection   budget  \
# 0  False  /cXQH2u7wUIX1eoIdEj51kHXoWhX.jpg                    NaN  1350000
# 1  False  /cbTvuGya7E1PnL8t95AWzumjqHg.jpg                    NaN        0
# 2  False                               NaN                    NaN        0
# 3  False                               NaN                    NaN        0
# 4  False                               NaN                    NaN        0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4                   [{'id': 10402, 'name': 'Music'}]
#
#                                             homepage      id    imdb_id  \
# 0  http://www.universalstudiosentertainment.com/l...     100  tt0120735
# 1                                                NaN  100017  tt0488903
# 2                                                NaN  100032  tt0099137
# 3                                                NaN  100034  tt0462634
# 4                                                NaN  100038        NaN
#
#   original_language                       original_title  ...    status  \
# 0                en  Lock, Stock and Two Smoking Barrels  ...  Released
# 1                de                             Verfolgt  ...  Released
# 2                en     The Great Los Angeles Earthquake  ...  Released
# 3                en     The Worst Horror Movie Ever Made  ...  Released
# 4                en                  Meshuggah - Nothing  ...  Released
#
#                                              tagline  \
# 0                A Disgrace to Criminals Everywhere.
# 1                                                NaN
# 2  There is no safe harbor, there is no escape......
# 3                                                NaN
# 4                                                NaN
#
#                                  title  video vote_average vote_count  \
# 0  Lock, Stock and Two Smoking Barrels  False          8.1       5798
# 1                            Punish Me  False          4.6         16
# 2     The Great Los Angeles Earthquake  False          6.9         13
# 3     The Worst Horror Movie Ever Made  False          3.0          8
# 4                  Meshuggah - Nothing  False          4.0          2
#
#    belongs_to_collection.id  belongs_to_collection.name  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#   belongs_to_collection.poster_path belongs_to_collection.backdrop_path
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
# [5 rows x 29 columns]

# %%
df_credits.head()
# Out:
#        id                                               cast  \
# 0     100  [{'adult': False, 'gender': 2, 'id': 973, 'kno...
# 1  100017  [{'adult': False, 'gender': 2, 'id': 5202, 'kn...
# 2  100032  [{'adult': False, 'gender': 1, 'id': 87038, 'k...
# 3  100034  [{'adult': False, 'gender': 0, 'id': 1022808, ...
# 4  100038                                                 []
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 960, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 2338, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 36116, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 99005, 'k...
# 4                                                 []

# %%
df_keywords.head()
# Out:
#        id                                           keywords
# 0     100  [{'id': 502, 'name': 'ambush'}, {'id': 567, 'n...
# 1  100017  [{'id': 2843, 'name': 'fetishism'}, {'id': 326...
# 2  100032  [{'id': 2708, 'name': 'hitman'}, {'id': 3521, ...
# 3  100034                                                 []
# 4  100038                                                 []

# %% [markdown]
# ### Three types of recommender systems
#
# 1. Demographic Filtering
# 2. Content Based Filtering
# 3. Collaborative Filtering

# %%
# join movies metadata and credits
df_movies_info = df_movies_metadata.merge(df_credits, on='id')
df_movies_info = df_movies_info.merge(df_keywords, on='id')

# %%
df_movies_info.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection   budget  \
# 0  False  /cXQH2u7wUIX1eoIdEj51kHXoWhX.jpg                    NaN  1350000
# 1  False  /cbTvuGya7E1PnL8t95AWzumjqHg.jpg                    NaN        0
# 2  False                               NaN                    NaN        0
# 3  False                               NaN                    NaN        0
# 4  False                               NaN                    NaN        0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4                   [{'id': 10402, 'name': 'Music'}]
#
#                                             homepage      id    imdb_id  \
# 0  http://www.universalstudiosentertainment.com/l...     100  tt0120735
# 1                                                NaN  100017  tt0488903
# 2                                                NaN  100032  tt0099137
# 3                                                NaN  100034  tt0462634
# 4                                                NaN  100038        NaN
#
#   original_language                       original_title  ...  video  \
# 0                en  Lock, Stock and Two Smoking Barrels  ...  False
# 1                de                             Verfolgt  ...  False
# 2                en     The Great Los Angeles Earthquake  ...  False
# 3                en     The Worst Horror Movie Ever Made  ...  False
# 4                en                  Meshuggah - Nothing  ...  False
#
#    vote_average vote_count belongs_to_collection.id  \
# 0           8.1       5798                      NaN
# 1           4.6         16                      NaN
# 2           6.9         13                      NaN
# 3           3.0          8                      NaN
# 4           4.0          2                      NaN
#
#   belongs_to_collection.name belongs_to_collection.poster_path  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
#
#    belongs_to_collection.backdrop_path  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 2, 'id': 973, 'kno...
# 1  [{'adult': False, 'gender': 2, 'id': 5202, 'kn...
# 2  [{'adult': False, 'gender': 1, 'id': 87038, 'k...
# 3  [{'adult': False, 'gender': 0, 'id': 1022808, ...
# 4                                                 []
#
#                                                 crew  \
# 0  [{'adult': False, 'gender': 2, 'id': 960, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 2338, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 36116, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 99005, 'k...
# 4                                                 []
#
#                                             keywords
# 0  [{'id': 502, 'name': 'ambush'}, {'id': 567, 'n...
# 1  [{'id': 2843, 'name': 'fetishism'}, {'id': 326...
# 2  [{'id': 2708, 'name': 'hitman'}, {'id': 3521, ...
# 3                                                 []
# 4                                                 []
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Demographic Filtering

# %% [markdown]
# Steps:
#
# 1. We require a metric to score or rate a movie.
# 2. Calculate the score for every movie.
# 3. Sort the scores and recommend the best rated movie to the users.

# %% [markdown]
# The average rating would be an obvious choice but this is not a fair score to use since a movie with a 9.3 average rating with 3 voters should not be considered better than a a movie with 8.8 average rating with 40 voters. I will use IMDB's weighted rating which is given as:

# %% [markdown]
# Weighted Rating (WR) = $(\frac{v}{v + m} \cdot R) + (\frac{m}{v + m} \cdot C)$ where,
#
# - v is the number of votes for the movie,
# - m is the minimum votes required to be considered,
# - R is the average rating of the movie, and
# - C is the average rating across the whole report

# %%
df_movies_info.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection   budget  \
# 0  False  /cXQH2u7wUIX1eoIdEj51kHXoWhX.jpg                    NaN  1350000
# 1  False  /cbTvuGya7E1PnL8t95AWzumjqHg.jpg                    NaN        0
# 2  False                               NaN                    NaN        0
# 3  False                               NaN                    NaN        0
# 4  False                               NaN                    NaN        0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4                   [{'id': 10402, 'name': 'Music'}]
#
#                                             homepage      id    imdb_id  \
# 0  http://www.universalstudiosentertainment.com/l...     100  tt0120735
# 1                                                NaN  100017  tt0488903
# 2                                                NaN  100032  tt0099137
# 3                                                NaN  100034  tt0462634
# 4                                                NaN  100038        NaN
#
#   original_language                       original_title  ...  video  \
# 0                en  Lock, Stock and Two Smoking Barrels  ...  False
# 1                de                             Verfolgt  ...  False
# 2                en     The Great Los Angeles Earthquake  ...  False
# 3                en     The Worst Horror Movie Ever Made  ...  False
# 4                en                  Meshuggah - Nothing  ...  False
#
#    vote_average vote_count belongs_to_collection.id  \
# 0           8.1       5798                      NaN
# 1           4.6         16                      NaN
# 2           6.9         13                      NaN
# 3           3.0          8                      NaN
# 4           4.0          2                      NaN
#
#   belongs_to_collection.name belongs_to_collection.poster_path  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               NaN
#
#    belongs_to_collection.backdrop_path  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 2, 'id': 973, 'kno...
# 1  [{'adult': False, 'gender': 2, 'id': 5202, 'kn...
# 2  [{'adult': False, 'gender': 1, 'id': 87038, 'k...
# 3  [{'adult': False, 'gender': 0, 'id': 1022808, ...
# 4                                                 []
#
#                                                 crew  \
# 0  [{'adult': False, 'gender': 2, 'id': 960, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 2338, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 36116, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 99005, 'k...
# 4                                                 []
#
#                                             keywords
# 0  [{'id': 502, 'name': 'ambush'}, {'id': 567, 'n...
# 1  [{'id': 2843, 'name': 'fetishism'}, {'id': 326...
# 2  [{'id': 2708, 'name': 'hitman'}, {'id': 3521, ...
# 3                                                 []
# 4                                                 []
#
# [5 rows x 32 columns]

# %%
# determine min number of votes required to be considered
min_votes = df_movies_info['vote_count'].quantile(0.9)
min_votes
# Out:
# 75.0

# %%
# calculate average rating across the whole report
overall_average_rating = df_movies_info['vote_average'].mean()
overall_average_rating
# Out:
# 4.7209208757213394

# %%
# filter dataset to exclude movies with less than m votes
df_movies_info_filtered = df_movies_info[df_movies_info['vote_count'] >= min_votes]

# %%
len(df_movies_info_filtered) / len(df_movies_info)
# Out:
# 0.10054137664346481

# %%
# function to calculate weighted rating
def calculate_weigted_rating(x, m=min_votes, C=overall_average_rating):
    R = x['vote_average']
    v = x['vote_count']
    result = ((v/(v+m)*R)) + ((m/(v+m))*C)
    return result

# %%
# create new column for weighted rating
df_movies_info_filtered['weighted_rating'] = df_movies_info_filtered.apply(
    lambda x: calculate_weigted_rating(x, min_votes, overall_average_rating), axis=1)
# Out:
# C:\Users\Dante\AppData\Local\Temp\ipykernel_15568\960925240.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies_info_filtered['weighted_rating'] = df_movies_info_filtered.apply(

# %%
# manually check some values to ensure function worked correctly
df_movies_info_filtered[['vote_average',
                         'vote_count', 'weighted_rating']].head()
# Out:
#     vote_average  vote_count  weighted_rating
# 0          8.100        5798         8.056848
# 6          5.538        2795         5.516648
# 8          6.600         124         5.891804
# 28         5.100          90         4.927691
# 38         6.600         123         5.888228

# %%
# sort dataframe based on weighted rating
df_movies_info_filtered = df_movies_info_filtered.sort_values(
    'weighted_rating', ascending=False)

# %%
# look at top 25 movies
df_movies_info_filtered[['title', 'vote_average',
                         'vote_count', 'weighted_rating']].head(25)
# Out:
#                                                    title  vote_average  \
# 22666                                      The Godfather         8.715
# 23672                           The Shawshank Redemption         8.702
# 22687                              The Godfather Part II         8.601
# 25229                                   Schindler's List         8.565
# 9944                                     The Dark Knight         8.506
# 24896                                       12 Angry Men         8.534
# 26305                                     The Green Mile         8.500
# 4496                                       Spirited Away         8.500
# 28868                                       Pulp Fiction         8.491
# 4671                                        Forrest Gump         8.480
# 3050       The Lord of the Rings: The Return of the King         8.472
# 25311                     The Good, the Bad and the Ugly         8.484
# 30119                                         GoodFellas         8.464
# 28320                                  Life Is Beautiful         8.452
# 27018                                         Fight Club         8.432
# 24610                                      Seven Samurai         8.500
# 17759                            The Empire Strikes Back         8.400
# 2647   The Lord of the Rings: The Fellowship of the Ring         8.394
# 10446                                       Interstellar         8.389
# 27787                                        City of God         8.420
# 26502                    One Flew Over the Cuckoo's Nest         8.400
# 26870                                             Psycho         8.400
# 26247                               Howl's Moving Castle         8.400
# 25216                                        The Pianist         8.400
# 2820               The Lord of the Rings: The Two Towers         8.375
#
#        vote_count  weighted_rating
# 22666       17427         8.697884
# 23672       23237         8.689192
# 22687       10552         8.573616
# 25229       13729         8.544114
# 9944        29141         8.496283
# 24896        7021         8.493698
# 26305       15013         8.481215
# 4496        13917         8.479743
# 28868       24615         8.479548
# 4671        24102         8.468339
# 3050        21059         8.458688
# 25311        7186         8.445131
# 30119       10963         8.438567
# 28320       11681         8.428197
# 27018       25769         8.421230
# 24610        2941         8.406024
# 17759       15026         8.381728
# 2647        22221         8.381644
# 10446       30464         8.379992
# 27787        6268         8.376262
# 26502        9169         8.370150
# 26870        8764         8.368783
# 26247        7986         8.365770
# 25216        7841         8.365143
# 2820        19310         8.360862

# %% [markdown]
# Lets try generating Top 25 lists for specific genres of movies

# %%
# convert from json to list for genre column
df_movies_info['genres'] = df_movies_info['genres'].fillna('[]').apply(
    literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])
print(df_movies_info['genres'].head())
# Out:
# 0              [Comedy, Crime]
# 1                      [Drama]
# 2    [Drama, Action, TV Movie]
# 3             [Horror, Comedy]
# 4                      [Music]
# Name: genres, dtype: object

# %%
# split genres columns into individual rows
genre_col = df_movies_info.apply(lambda x: pd.Series(
    x['genres'], dtype='object'), axis=1).stack().reset_index(level=1, drop=True)
genre_col.name = 'genre'
df_movies_info_genre_split = df_movies_info.drop(
    'genres', axis=1).join(genre_col)

# %%
# function to return dataframe of top N movies for a particular genre
def top_N_movies(genre, N, percentile=0.9):
    df_movies_info_specific_genre = df_movies_info_genre_split[
        df_movies_info_genre_split['genre'] == genre]

    min_votes = df_movies_info_specific_genre['vote_count'].quantile(
        percentile)

    overall_average_rating = df_movies_info_specific_genre['vote_average'].mean(
    )

    df_movies_info_specific_genre_filtered = df_movies_info_specific_genre[
        df_movies_info_specific_genre['vote_count'] >= min_votes]

    df_movies_info_specific_genre_filtered['weighted_rating'] = df_movies_info_specific_genre_filtered.apply(
        lambda x: calculate_weigted_rating(x, min_votes, overall_average_rating), axis=1)

    df_movies_info_specific_genre_filtered = df_movies_info_specific_genre_filtered.sort_values(
        'weighted_rating', ascending=False)

    return df_movies_info_specific_genre_filtered[:N]

# %%
genre_col.unique()
# Out:
# array(['Comedy', 'Crime', 'Drama', 'Action', 'TV Movie', 'Horror',
#        'Music', 'Romance', 'Documentary', 'Family', 'Western',
#        'Animation', 'Thriller', 'War', 'Science Fiction', 'Fantasy',
#        'Adventure', 'Mystery', 'History'], dtype=object)

# %%
top_N_movies('Romance', 25)
# Out:
# C:\Users\Dante\AppData\Local\Temp\ipykernel_15568\2018519160.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies_info_specific_genre_filtered['weighted_rating'] = df_movies_info_specific_genre_filtered.apply(
#        adult                     backdrop_path  belongs_to_collection  \
# 4671   False  /3h1JZGDhZ8nzxdgvkxha0qBqi05.jpg                    NaN
# 24853  False   /W1ffLQGHoxfAOq0ZYdPtJlvAdb.jpg                    NaN
# 25260  False  /pGWVZT13HBz70L30ytRMXpNkTgU.jpg                    NaN
# 23789  False  /wOfzdzC0QZyhUIlyjeMuUYSb8Ax.jpg                    NaN
# 25371  False  /pgEWI7yGYF0mM5Uf1YxSOHsBkJR.jpg                    NaN
# 32008  False  /g7KmJaGFvST5cyvA71V6epKAqIC.jpg                    NaN
# 27775  False  /6VmFqApQRyZZzmiGOQq2C92jyvH.jpg                    NaN
# 18997  False  /9Y9K6LeLrMeofOvX7hZW36Aj3OG.jpg                    NaN
# 22676  False  /5zTwAcnI3zCJ0mucPPnoBtkSWEV.jpg                    NaN
# 25660  False  /vVBcIN68kFq681b4lObiNJhEVro.jpg                    NaN
# 9452   False  /sPPsR9f4K0movWVQ99u4uMqFzEL.jpg                    NaN
# 32562  False  /n0Cju2Eu3VyrUFl32thblHFWznA.jpg                    NaN
# 3235   False  /qo7QDVyJwwM9pMo7huxvV7oX84Y.jpg                    NaN
# 23763  False  /vRTKNKNWLZ22fAgPa5kY8wT2b1F.jpg                    NaN
# 30121  False  /ft8WRF2xqEwwGWa59naDUybKTAx.jpg                    NaN
# 30037  False  /qA2TyqPldTtoTVY3LKrNIG5g6bH.jpg                    NaN
# 31481  False  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                    NaN
# 7198   False  /3KyAxlakmcyHWqlcxgIxMQnSilk.jpg                    NaN
# 6027   False  /yPgAHVzCF0yJGhxupwVwknOHdJj.jpg                    NaN
# 24009  False  /vbba0jXLjghW4nNzte51d8XWSvq.jpg                    NaN
# 24180  False  /okdg55jhsr9k1F2lxsZoQncrLZL.jpg                    NaN
# 11561  False  /uNLIMPxknsV4n3IAEDpS1iqF5dm.jpg                    NaN
# 29221  False  /8n9dYsTbXTykzm2Nuy7R2ftapXQ.jpg                    NaN
# 26216  False  /2fswjyrY3GEzeoVn6mF8pNeNcgf.jpg                    NaN
# 27982  False  /tqlCsB6AFjQ9dpAOHkd3sEdFS13.jpg                    NaN
#
#           budget                                           homepage      id  \
# 4671    55000000  https://www.paramountmovies.com/movies/forrest...      13
# 24853   20000000                     http://www.eternalsunshine.com      38
# 25260    2479000                                                NaN     426
# 23789     878000                                                NaN     289
# 25371   28000000  http://www.prideandprejudicemovie.net/splash.html    4348
# 32008    2540800                                                NaN     872
# 27775  200000000                                                NaN     597
# 18997   10000000              https://www.miramax.com/movie/amelie/     194
# 22676    2883848                                                NaN     239
# 25660   60000000                      http://www.abeautifulmind.com     453
# 9452    23000000                        http://www.herthemovie.com/  152601
# 32562    1500000  https://www.charliechaplin.com/en/films/5-City...     901
# 3235    12000000                                                NaN  122906
# 23763    3000000                                                NaN     284
# 30121    4000000                                                NaN     770
# 30037    2500000          https://www.warnerbros.com/movies/sunrise      76
# 31481     150000                                                NaN     843
# 7198    14000000                   http://www.brokebackmountain.com     142
# 6027     1000000    https://www.20thcenturystudios.com/movies/rocky    1366
# 24009   47000000                                                NaN   31011
# 24180   11000000                                                NaN    3175
# 11561   20000000                                                NaN     162
# 29221    4000000                                                NaN     703
# 26216  150000000                     http://www.benjaminbutton.com/    4922
# 27982   30000000                                                NaN    6075
#
#          imdb_id original_language                         original_title  \
# 4671   tt0109830                en                           Forrest Gump
# 24853  tt0338013                en  Eternal Sunshine of the Spotless Mind
# 25260  tt0052357                en                                Vertigo
# 23789  tt0034583                en                             Casablanca
# 25371  tt0414387                en                      Pride & Prejudice
# 32008  tt0045152                en                    Singin' in the Rain
# 27775  tt0120338                en                                Titanic
# 18997  tt0211915                fr    Le Fabuleux Destin d'Amélie Poulain
# 22676  tt0053291                en                       Some Like It Hot
# 25660  tt0268978                en                       A Beautiful Mind
# 9452   tt1798709                en                                    Her
# 32562  tt0021749                en                            City Lights
# 3235   tt2194499                en                             About Time
# 23763  tt0053604                en                          The Apartment
# 30121  tt0031381                en                     Gone with the Wind
# 30037  tt0112471                en                         Before Sunrise
# 31481  tt0118694                cn                                   花樣年華
# 7198   tt0388795                en                     Brokeback Mountain
# 6027   tt0075148                en                                  Rocky
# 24009  tt0485947                en                             Mr. Nobody
# 24180  tt0072684                en                           Barry Lyndon
# 11561  tt0099487                en                    Edward Scissorhands
# 29221  tt0075686                en                             Annie Hall
# 26216  tt0421715                en    The Curious Case of Benjamin Button
# 27982  tt0106519                en                          Carlito's Way
#
#                                                 overview  ...  vote_count  \
# 4671   A man with a low IQ has accomplished great thi...  ...       24102
# 24853  Joel Barish, heartbroken that his girlfriend u...  ...       13043
# 25260  A retired San Francisco detective suffering fr...  ...        4927
# 23789  In Casablanca, Morocco in December 1941, a cyn...  ...        4584
# 25371  A story of love and life among the landed Engl...  ...        6966
# 32008  In 1927 Hollywood, a silent film production co...  ...        2663
# 27775  101-year-old Rose DeWitt Bukater tells the sto...  ...       22225
# 18997  At a tiny Parisian café, the adorable yet pain...  ...       10270
# 22676  Two musicians witness a mob hit and struggle t...  ...        2950
# 25660  John Nash is a brilliant but asocial mathemati...  ...        9043
# 9452   In the not so distant future, Theodore, a lone...  ...       12811
# 32562  In this sound-era silent film, a tramp falls i...  ...        1802
# 3235   The night after another unsatisfactory New Yea...  ...        7390
# 23763  Bud Baxter is a minor clerk in a huge New York...  ...        1875
# 30121  The spoiled daughter of a Georgia plantation o...  ...        3482
# 30037  On his way to Vienna, American Jesse meets Cél...  ...        3443
# 31481  Hong Kong, 1962: Chow Mo-Wan and Su Li-Zhen mo...  ...        2109
# 7198   Two modern-day cowboys meet on a shepherding j...  ...        6102
# 6027   When world heavyweight boxing champion, Apollo...  ...        6606
# 24009  Nemo Nobody leads an ordinary existence with h...  ...        5341
# 24180  An Irish rogue uses his cunning and wit to wor...  ...        2378
# 11561  A small suburban town receives a visit from a ...  ...       11535
# 29221  New York comedian Alvy Singer falls in love wi...  ...        3384
# 26216  I was born under unusual circumstances. And so...  ...       11335
# 27982  A Puerto-Rican ex-con, just released from pris...  ...        2701
#
#       belongs_to_collection.id belongs_to_collection.name  \
# 4671                       NaN                        NaN
# 24853                      NaN                        NaN
# 25260                      NaN                        NaN
# 23789                      NaN                        NaN
# 25371                      NaN                        NaN
# 32008                      NaN                        NaN
# 27775                      NaN                        NaN
# 18997                      NaN                        NaN
# 22676                      NaN                        NaN
# 25660                      NaN                        NaN
# 9452                       NaN                        NaN
# 32562                      NaN                        NaN
# 3235                       NaN                        NaN
# 23763                      NaN                        NaN
# 30121                      NaN                        NaN
# 30037                 123800.0       Before... Collection
# 31481                      NaN                        NaN
# 7198                       NaN                        NaN
# 6027                    1575.0           Rocky Collection
# 24009                      NaN                        NaN
# 24180                      NaN                        NaN
# 11561                      NaN                        NaN
# 29221                      NaN                        NaN
# 26216                      NaN                        NaN
# 27982                 625861.0   Carlito's Way Collection
#
#       belongs_to_collection.poster_path belongs_to_collection.backdrop_path  \
# 4671                                NaN                                 NaN
# 24853                               NaN                                 NaN
# 25260                               NaN                                 NaN
# 23789                               NaN                                 NaN
# 25371                               NaN                                 NaN
# 32008                               NaN                                 NaN
# 27775                               NaN                                 NaN
# 18997                               NaN                                 NaN
# 22676                               NaN                                 NaN
# 25660                               NaN                                 NaN
# 9452                                NaN                                 NaN
# 32562                               NaN                                 NaN
# 3235                                NaN                                 NaN
# 23763                               NaN                                 NaN
# 30121                               NaN                                 NaN
# 30037  /bBS1CfspKXq5RBok85hYvtW9ZwE.jpg    /to3l6Gwzd7FGWa9Spc708IP1K7l.jpg
# 31481                               NaN                                 NaN
# 7198                                NaN                                 NaN
# 6027   /fKe9y1AJHEzoiHwSrjfwyinuCE8.jpg     /JhGydj4q5y8MoWZFyj15yKNrzC.jpg
# 24009                               NaN                                 NaN
# 24180                               NaN                                 NaN
# 11561                               NaN                                 NaN
# 29221                               NaN                                 NaN
# 26216                               NaN                                 NaN
# 27982  /6cfxrG33T47k1gdzIej8qhwM3eJ.jpg    /5mdKbMjR7dxUBNzjB9BUqGJPGBT.jpg
#
#                                                     cast  \
# 4671   [{'adult': False, 'gender': 2, 'id': 31, 'know...
# 24853  [{'adult': False, 'gender': 2, 'id': 206, 'kno...
# 25260  [{'adult': False, 'gender': 2, 'id': 854, 'kno...
# 23789  [{'adult': False, 'gender': 2, 'id': 4110, 'kn...
# 25371  [{'adult': False, 'gender': 1, 'id': 116, 'kno...
# 32008  [{'adult': False, 'gender': 2, 'id': 13294, 'k...
# 27775  [{'adult': False, 'gender': 1, 'id': 204, 'kno...
# 18997  [{'adult': False, 'gender': 1, 'id': 2405, 'kn...
# 22676  [{'adult': False, 'gender': 2, 'id': 3150, 'kn...
# 25660  [{'adult': False, 'gender': 2, 'id': 934, 'kno...
# 9452   [{'adult': False, 'gender': 2, 'id': 73421, 'k...
# 32562  [{'adult': False, 'gender': 2, 'id': 13848, 'k...
# 3235   [{'adult': False, 'gender': 2, 'id': 93210, 'k...
# 23763  [{'adult': False, 'gender': 2, 'id': 3151, 'kn...
# 30121  [{'adult': False, 'gender': 1, 'id': 10538, 'k...
# 30037  [{'adult': False, 'gender': 2, 'id': 569, 'kno...
# 31481  [{'adult': False, 'gender': 2, 'id': 1337, 'kn...
# 7198   [{'adult': False, 'gender': 2, 'id': 1810, 'kn...
# 6027   [{'adult': False, 'gender': 2, 'id': 16483, 'k...
# 24009  [{'adult': False, 'gender': 2, 'id': 7499, 'kn...
# 24180  [{'adult': False, 'gender': 2, 'id': 31070, 'k...
# 11561  [{'adult': False, 'gender': 2, 'id': 85, 'know...
# 29221  [{'adult': False, 'gender': 2, 'id': 1243, 'kn...
# 26216  [{'adult': False, 'gender': 2, 'id': 287, 'kno...
# 27982  [{'adult': False, 'gender': 2, 'id': 1158, 'kn...
#
#                                                     crew  \
# 4671   [{'adult': False, 'gender': 2, 'id': 37, 'know...
# 24853  [{'adult': False, 'gender': 2, 'id': 201, 'kno...
# 25260  [{'adult': False, 'gender': 2, 'id': 1045, 'kn...
# 23789  [{'adult': False, 'gender': 2, 'id': 2005, 'kn...
# 25371  [{'adult': False, 'gender': 1, 'id': 474, 'kno...
# 32008  [{'adult': False, 'gender': 2, 'id': 14681, 'k...
# 27775  [{'adult': False, 'gender': 2, 'id': 900, 'kno...
# 18997  [{'adult': False, 'gender': 2, 'id': 2401, 'kn...
# 22676  [{'adult': False, 'gender': 2, 'id': 3146, 'kn...
# 25660  [{'adult': False, 'gender': 2, 'id': 151, 'kno...
# 9452   [{'adult': False, 'gender': 2, 'id': 202, 'kno...
# 32562  [{'adult': False, 'gender': 2, 'id': 3945, 'kn...
# 3235   [{'adult': False, 'gender': 1, 'id': 1266, 'kn...
# 23763  [{'adult': False, 'gender': 2, 'id': 491, 'kno...
# 30121  [{'adult': False, 'gender': 2, 'id': 2774, 'kn...
# 30037  [{'adult': False, 'gender': 2, 'id': 564, 'kno...
# 31481  [{'adult': False, 'gender': 2, 'id': 1357, 'kn...
# 7198   [{'adult': False, 'gender': 1, 'id': 2952, 'kn...
# 6027   [{'adult': False, 'gender': 2, 'id': 1918, 'kn...
# 24009  [{'adult': False, 'gender': 2, 'id': 19986, 'k...
# 24180  [{'adult': False, 'gender': 2, 'id': 240, 'kno...
# 11561  [{'adult': False, 'gender': 2, 'id': 1226, 'kn...
# 29221  [{'adult': False, 'gender': 1, 'id': 1046, 'kn...
# 26216  [{'adult': False, 'gender': 2, 'id': 27, 'know...
# 27982  [{'adult': False, 'gender': 2, 'id': 508, 'kno...
#
#                                                 keywords    genre  \
# 4671   [{'id': 422, 'name': 'vietnam veteran'}, {'id'...  Romance
# 24853  [{'id': 242, 'name': 'new york city'}, {'id': ...  Romance
# 25260  [{'id': 582, 'name': 'san francisco, californi...  Romance
# 23789  [{'id': 128, 'name': 'love triangle'}, {'id': ...  Romance
# 25371  [{'id': 392, 'name': 'england'}, {'id': 818, '...  Romance
# 32008  [{'id': 3177, 'name': 'fan'}, {'id': 3748, 'na...  Romance
# 27775  [{'id': 793, 'name': 'drowning'}, {'id': 2227,...  Romance
# 18997  [{'id': 90, 'name': 'paris, france'}, {'id': 1...  Romance
# 22676  [{'id': 520, 'name': 'chicago, illinois'}, {'i...  Romance
# 25660  [{'id': 30, 'name': 'individual'}, {'id': 222,...  Romance
# 9452   [{'id': 310, 'name': 'artificial intelligence'...  Romance
# 32562  [{'id': 1252, 'name': 'suicide attempt'}, {'id...  Romance
# 3235   [{'id': 212, 'name': 'london, england'}, {'id'...  Romance
# 23763  [{'id': 242, 'name': 'new york city'}, {'id': ...  Romance
# 30121  [{'id': 393, 'name': 'civil war'}, {'id': 697,...  Romance
# 30037  [{'id': 813, 'name': 'sunrise'}, {'id': 814, '...  Romance
# 31481  [{'id': 596, 'name': 'adultery'}, {'id': 725, ...  Romance
# 7198   [{'id': 548, 'name': 'countryside'}, {'id': 10...  Romance
# 6027   [{'id': 240, 'name': 'underdog'}, {'id': 276, ...  Romance
# 24009  [{'id': 3667, 'name': 'time'}, {'id': 9887, 'n...  Romance
# 24180  [{'id': 395, 'name': 'gambling'}, {'id': 818, ...  Romance
# 11561  [{'id': 240, 'name': 'underdog'}, {'id': 699, ...  Romance
# 29221  [{'id': 242, 'name': 'new york city'}, {'id': ...  Romance
# 26216  [{'id': 2913, 'name': 'diary'}, {'id': 3588, '...  Romance
# 27982  [{'id': 242, 'name': 'new york city'}, {'id': ...  Romance
#
#       weighted_rating
# 4671         8.431216
# 24853        8.022287
# 25260        7.992660
# 23789        7.982338
# 25371        7.958144
# 32008        7.845676
# 27775        7.841617
# 18997        7.812409
# 22676        7.803780
# 25660        7.797760
# 9452         7.790069
# 32562        7.788880
# 3235         7.777953
# 23763        7.742574
# 30121        7.740945
# 30037        7.738314
# 31481        7.683162
# 7198         7.659470
# 6027         7.647088
# 24009        7.638704
# 24180        7.637869
# 11561        7.625761
# 29221        7.555211
# 26216        7.527876
# 27982        7.523036
#
# [25 rows x 33 columns]

# %%
top_N_movies('Science Fiction', 25).head()
# Out:
# C:\Users\Dante\AppData\Local\Temp\ipykernel_15568\2018519160.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies_info_specific_genre_filtered['weighted_rating'] = df_movies_info_specific_genre_filtered.apply(
#        adult                     backdrop_path  belongs_to_collection  \
# 10446  False  /rAiYTfKGqDCRIIqo664sY9XZIvQ.jpg                    NaN
# 23433  False  /s3TBrRGB1iav7gFOCNx3H31MoES.jpg                    NaN
# 17759  False  /dMZxEdrWIzUmUoOz2zvmFuutbj7.jpg                    NaN
# 572    False  /5bzPWQ2dFUl2aZKkp7ILJVVkRed.jpg                    NaN
# 27899  False  /waCRuAW5ocONRehP556vPexVXA9.jpg                    NaN
#
#           budget                                           homepage      id  \
# 10446  165000000                  http://www.interstellarmovie.net/  157336
# 23433  160000000        https://www.warnerbros.com/movies/inception   27205
# 17759   18000000  http://www.starwars.com/films/star-wars-episod...    1891
# 572     19000000  http://www.backtothefuture.com/movies/backtoth...     105
# 27899   63000000                   http://www.warnerbros.com/matrix     603
#
#          imdb_id original_language           original_title  \
# 10446  tt0816692                en             Interstellar
# 23433  tt1375666                en                Inception
# 17759  tt0080684                en  The Empire Strikes Back
# 572    tt0088763                en       Back to the Future
# 27899  tt0133093                en               The Matrix
#
#                                                 overview  ...  vote_count  \
# 10446  The adventures of a group of explorers who mak...  ...       30464
# 23433  Cobb, a skilled thief who commits corporate es...  ...       33132
# 17759  The epic saga continues as Luke Skywalker, in ...  ...       15026
# 572    Eighties teenager Marty McFly is accidentally ...  ...       17522
# 27899  Set in the 22nd century, The Matrix tells the ...  ...       22774
#
#       belongs_to_collection.id     belongs_to_collection.name  \
# 10446                      NaN                            NaN
# 23433                      NaN                            NaN
# 17759                     10.0           Star Wars Collection
# 572                      264.0  Back to the Future Collection
# 27899                   2344.0          The Matrix Collection
#
#       belongs_to_collection.poster_path belongs_to_collection.backdrop_path  \
# 10446                               NaN                                 NaN
# 23433                               NaN                                 NaN
# 17759  /gq5Wi7i4SF3lo4HHkJasDV95xI9.jpg    /d8duYyyC9J5T825Hg7grmaabfxQ.jpg
# 572    /5Xsu2o5IsZRuuxCEVZ9nVve21FP.jpg    /AqQotqj7XOI6GjB28nhMMa8YzOT.jpg
# 27899  /bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg    /bRm2DEgUiYciDw3myHuYFInD7la.jpg
#
#                                                     cast  \
# 10446  [{'adult': False, 'gender': 2, 'id': 10297, 'k...
# 23433  [{'adult': False, 'gender': 2, 'id': 6193, 'kn...
# 17759  [{'adult': False, 'gender': 2, 'id': 2, 'known...
# 572    [{'adult': False, 'gender': 2, 'id': 521, 'kno...
# 27899  [{'adult': False, 'gender': 2, 'id': 6384, 'kn...
#
#                                                     crew  \
# 10446  [{'adult': False, 'gender': 2, 'id': 947, 'kno...
# 23433  [{'adult': False, 'gender': 2, 'id': 947, 'kno...
# 17759  [{'adult': False, 'gender': 2, 'id': 1, 'known...
# 572    [{'adult': False, 'gender': 2, 'id': 37, 'know...
# 27899  [{'adult': False, 'gender': 2, 'id': 123, 'kno...
#
#                                                 keywords            genre  \
# 10446  [{'id': 310, 'name': 'artificial intelligence'...  Science Fiction
# 23433  [{'id': 90, 'name': 'paris, france'}, {'id': 4...  Science Fiction
# 17759  [{'id': 526, 'name': 'rebel'}, {'id': 803, 'na...  Science Fiction
# 572    [{'id': 389, 'name': 'clock tower'}, {'id': 39...  Science Fiction
# 27899  [{'id': 83, 'name': 'saving the world'}, {'id'...  Science Fiction
#
#       weighted_rating
# 10446        8.190308
# 23433        8.179947
# 17759        8.020315
# 572          7.988157
# 27899        7.951657
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Content Based Filtering

# %% [markdown]
# In this recommender system, the contents of the movie (overview, genre, cast, crew, keywords, etc) is used to determine its similarity with other movies. The movies which are most similar are recommended.

# %% [markdown]
# #### 1. Plot Description Based Recommender

# %%
df_movies_info['overview']
# Out:
# 0        A card shark and his unwillingly-enlisted frie...
# 1        Angelina Maccarone's intense drama deals with ...
# 2        After a series of small tremors in Los Angeles...
# 3        A group of friends get together for a card gam...
# 4                             Live content from bonus DVD.
#                                ...
# 33613    Nicholas, a young man with limited resources, ...
# 33614    Everything you've ever wanted to know about Sa...
# 33615    Donald is washing windows on a high-rise; Plut...
# 33616    Johann Bach teams up with the mysterious Josh ...
# 33617    The earliest Nazi propaganda film by Leni Rief...
# Name: overview, Length: 33618, dtype: object

# %%
# drop those with empty overview
df_movies_info_no_empty_overview = df_movies_info.dropna(
    subset=['overview']).reset_index()

# %%
# define tfidf vectorizer and remove all english stop words
tfidf = TfidfVectorizer(stop_words='english', use_idf=True)
tfidf_matrix = tfidf.fit_transform(
    df_movies_info_no_empty_overview['overview'])
tfidf_matrix.shape
# Out:
# (30864, 68854)

# %%
df_tfidf = pd.DataFrame(tfidf_matrix[0].T.todense(
), index=tfidf.get_feature_names_out(), columns=['tfidf'])

# %% [markdown]
# There are almost 70,000 different words used to describe the 30,000 movies in the dataaset.
# Using this matrix, we will calculate a similarity score. We will use the cosine similarity score.

# %% [markdown]
# The cosine similarity score computes a numeric quantity that describes the similarity between two movies. Mathematically, it is defined as:
# $cosine(x,y) = \frac{x. y^\intercal}{||x||.||y||} $
#
# As we already have the tf-idf vectorizer, we can directlyy get the cosine similarity score by computing the dot product.

# %%
# compute cosine similarity
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# create map of index and movie titles
indices = pd.Series(df_movies_info_no_empty_overview.index,
                    index=df_movies_info_no_empty_overview['title'])

# %% [markdown]
# Steps:
#
# 1. Get index of the input movie title.
# 2. Get list of cosine similarity scores for that particular movies with all other movies. Convert it into a list. of tuples where the first element is its index and the second is the cosine similarity score.
# 3. Sort the list of tuples based on the cosine similarity score.
# 4. Get the top 10 elements of this list, ignoring the first element as it refers to the input movie.
# 5. Return the titles corresponding to the indices of the top elements

# %%
# function to take in a movie title as input and output the N most similar movies
def get_recommendations(title, N, indices, cosine_sim, df):
    # get index of the input movie
    index = indices[title]

    # get the similarity scores for all movies with the input movie
    scores = list(enumerate(cosine_sim[index]))

    # sort the movies based on the similarity scores
    scores = sorted(scores, key=lambda x: x[1], reverse=True)

    # get the scores of the top N most similar movies
    scores = scores[1:N+1]

    # get the movie indices
    movie_indices = [i[0] for i in scores]

    # return the top N most similar movies
    result = df['title'].iloc[movie_indices]
    return result

# %%
get_recommendations('The Dark Knight', 10, indices, cosine_sim, df_movies_info_no_empty_overview)
# Out:
# 21349                                               Batman
# 23026                                       Batman Forever
# 6098                                  Fight Batman, Fight!
# 12329    Batman and Me: A Devotion to Destiny, the Bob ...
# 21458                                        Batman Begins
# 23037                                       Batman & Robin
# 13827       Lego Batman: The Movie - DC Super Heroes Unite
# 15658                                          Batman Tech
# 26894                              The Mechanical Monsters
# 3600                                                Batman
# Name: title, dtype: object

# %%
get_recommendations('Toy Story', 10, indices, cosine_sim, df_movies_info_no_empty_overview)
# Out:
# 16539             The Bees' Buzz
# 19400            Show Biz Beagle
# 26636     The 40 Year Old Virgin
# 19434                 Lotsa Luck
# 19420           Ship a-Hoy Woody
# 13200         The Rasslin' Match
# 19411           Wild Bill Hiccup
# 14616                 Hot Splash
# 19435    Hook, Line, and Stinker
# 750            The Violent Breed
# Name: title, dtype: object

# %% [markdown]
# #### 2. Credits, Genres and Keywords Based Recommender

# %% [markdown]
# From the cast, crew and keywords features, we will extract the three most important actors, the director and the keywords associated with that movie.

# %%
df_movies_info['cast']
# Out:
# 0        [{'adult': False, 'gender': 2, 'id': 973, 'kno...
# 1        [{'adult': False, 'gender': 2, 'id': 5202, 'kn...
# 2        [{'adult': False, 'gender': 1, 'id': 87038, 'k...
# 3        [{'adult': False, 'gender': 0, 'id': 1022808, ...
# 4                                                       []
#                                ...
# 33613    [{'adult': False, 'gender': 2, 'id': 222484, '...
# 33614    [{'adult': False, 'gender': 2, 'id': 120576, '...
# 33615    [{'adult': False, 'gender': 2, 'id': 78077, 'k...
# 33616    [{'adult': False, 'gender': 0, 'id': 1022748, ...
# 33617    [{'adult': False, 'gender': 2, 'id': 10280, 'k...
# Name: cast, Length: 33618, dtype: object

# %%
# parse each column into their corresponding python objects
# skip genres columns because it has already been parsed
features = ['cast', 'crew', 'keywords']

for feature in features:
    df_movies_info[feature] = df_movies_info[feature].apply(literal_eval)

# %%
# function to get the director name from the crew feature
def get_director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %%
# function to get a list of the first 3 elements or entire list, whichever is more
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        if len(names) > 3:
            names = names[:3]
        return names

    return []

# %%
df_movies_info['director'] = df_movies_info['crew'].apply(get_director)

features = ['cast', 'keywords']
for feature in features:
    df_movies_info[feature] = df_movies_info[feature].apply(get_list)

# %%
df_movies_info[['title', 'director', 'cast', 'keywords', 'genres']].head()
# Out:
#                                  title            director  \
# 0  Lock, Stock and Two Smoking Barrels         Guy Ritchie
# 1                            Punish Me  Angelina Maccarone
# 2     The Great Los Angeles Earthquake       Larry Elikann
# 3     The Worst Horror Movie Ever Made          Bill Zebub
# 4                  Meshuggah - Nothing                 NaN
#
#                                              cast  \
# 0    [Jason Flemyng, Dexter Fletcher, Nick Moran]
# 1  [Kostja Ullmann, Maren Kroymann, Moritz Grove]
# 2     [Joanna Kerns, Dan Lauria, Bonnie Bartlett]
# 3   [Rocco Martone, Jeanne Potter, Elaine Tuttle]
# 4                                              []
#
#                                         keywords                     genres
# 0                     [ambush, alcohol, shotgun]            [Comedy, Crime]
# 1             [fetishism, masochism, submissive]                    [Drama]
# 2  [hitman, earthquake, los angeles, california]  [Drama, Action, TV Movie]
# 3                                             []           [Horror, Comedy]
# 4                                             []                    [Music]

# %%
df_movies_info[df_movies_info['title'] == 'Batman'][['title', 'director', 'cast', 'keywords', 'genres']].head()
# Out:
#         title             director  \
# 3802   Batman      Lambert Hillyer
# 23232  Batman  Leslie H. Martinson
# 23319  Batman           Tim Burton
#
#                                                  cast  \
# 3802   [Lewis Wilson, Douglas Croft, J. Carrol Naish]
# 23232          [Adam West, Burt Ward, Lee Meriwether]
# 23319  [Michael Keaton, Jack Nicholson, Kim Basinger]
#
#                                      keywords  \
# 3802   [superhero, based on comic, espionage]
# 23232      [submarine, missile, shark attack]
# 23319  [double life, dual identity, chemical]
#
#                                                   genres
# 3802   [Action, Adventure, Crime, Science Fiction, Th...
# 23232                            [Action, Comedy, Crime]
# 23319                           [Fantasy, Action, Crime]

# %%
# function to convert all strings to lower case and strip name of spaces
def lower_and_strip_spaces(x):
    if isinstance(x, list):
        # for lists
        return [str.lower(i.replace(' ','')) for i in x]
    elif isinstance(x, str):
        # for strings
        return str.lower(x.replace(' ', ''))
    else:
        return ''

# %%
# apply function on features
features = ['cast', 'keywords', 'director', 'genres']

for feature in features:
    df_movies_info[feature] = df_movies_info[feature].apply(lower_and_strip_spaces)

# %%
df_movies_info[df_movies_info['title'] == 'Batman'][['title', 'director', 'cast', 'keywords', 'genres']].head()
# Out:
#         title           director                                         cast  \
# 3802   Batman     lamberthillyer   [lewiswilson, douglascroft, j.carrolnaish]
# 23232  Batman  leslieh.martinson          [adamwest, burtward, leemeriwether]
# 23319  Batman          timburton  [michaelkeaton, jacknicholson, kimbasinger]
#
#                                    keywords  \
# 3802   [superhero, basedoncomic, espionage]
# 23232     [submarine, missile, sharkattack]
# 23319  [doublelife, dualidentity, chemical]
#
#                                                   genres
# 3802   [action, adventure, crime, sciencefiction, thr...
# 23232                            [action, comedy, crime]
# 23319                           [fantasy, action, crime]

# %%
# function to create metadata soup from the columns
def create_soup(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast'])+ ' ' + x['director'] + ' ' + ' '.join(x['genres'])

# %%
# create metadata soup
df_movies_info['soup'] = df_movies_info.apply(create_soup, axis=1)

# %%
df_movies_info[df_movies_info['title'] == 'Batman'][['soup']].head()
# Out:
#                                                     soup
# 3802   superhero basedoncomic espionage lewiswilson d...
# 23232  submarine missile sharkattack adamwest burtwar...
# 23319  doublelife dualidentity chemical michaelkeaton...

# %%
df_movies_info['soup'][3802]
# Out:
# 'superhero basedoncomic espionage lewiswilson douglascroft j.carrolnaish lamberthillyer action adventure crime sciencefiction thriller war'

# %% [markdown]
# We use CountVectorizer() instead of tf-idf here so we do not down-weight the presence of an actor/director if they have acted or directed in more movies compared to others

# %%
count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(df_movies_info['soup'])
count_matrix.shape
# Out:
# (33618, 68764)

# %%
# compute cosine similarity
cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
indices = pd.Series(df_movies_info.index, index=df_movies_info['title'])

# %%
get_recommendations('The Godfather', 10, indices, cosine_sim2, df_movies_info)
# Out:
# 22687                        The Godfather Part II
# 22700                       The Godfather Part III
# 19468                                A Sneaky Boer
# 9695     Killing the Chickens to Scare the Monkeys
# 29649                          The Local Stigmatic
# 2893                       The Talented Mr. Ripley
# 1016                              The Price of Air
# 1693                                        Fetish
# 5047                             Dope Case Pending
# 5235                     C.C.Catch - Pretty Voices
# Name: title, dtype: object

# %%
get_recommendations('The Dark Knight', 10, indices, cosine_sim2, df_movies_info)
# Out:
# 23431                   Batman Begins
# 29271    Janice M Vidal Fairy Concert
# 1016                 The Price of Air
# 22895                     Harry Brown
# 1121                       Malevolent
# 2223                          Musafir
# 2503              How to Kill a Judge
# 3939                       A Red Bear
# 4018      Bad Azz Muthaz: Black Ninja
# 6013            Family: Ties of Blood
# Name: title, dtype: object

# %%
get_recommendations('Toy Story', 10, indices, cosine_sim2, df_movies_info)
# Out:
# 5705     Willy Fog in Journey to the Center of the Earth
# 31261                                         Alles Helt
# 33267                                    Superstar Goofy
# 11587                                             Pyrats
# 26188                                             Cars 2
# 32806                                               Cars
# 715                               Little Red Riding Hood
# 13097     Buck Denver Asks...Why Do We Call It Christmas
# 13332                     Donald Duck and his Companions
# 21140                                     When I Yoo Hoo
# Name: title, dtype: object

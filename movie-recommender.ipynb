# %% [markdown]
# # **Movie Recommender System**

# %%
# imports
import pandas as pd

# %%
df_movies = pd.read_csv('data/ml-25m/movies.csv')
df_ratings = pd.read_csv('data/ml-25m/ratings.csv')
df_tags = pd.read_csv('data/ml-25m/tags.csv')
df_links = pd.read_csv('data/ml-25m/links.csv')
df_movies_metadata = pd.read_csv('data/movies-metadata.csv')
df_credits = pd.read_csv('data/credits.csv')

# %%
df_movies_metadata.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection   budget  \
# 0  False  /cXQH2u7wUIX1eoIdEj51kHXoWhX.jpg                    NaN  1350000
# 1  False  /cbTvuGya7E1PnL8t95AWzumjqHg.jpg                    NaN        0
# 2  False                               NaN                    NaN        0
# 3  False                               NaN                    NaN        0
# 4  False                               NaN                    NaN        0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4                   [{'id': 10402, 'name': 'Music'}]
#
#                                             homepage      id    imdb_id  \
# 0  http://www.universalstudiosentertainment.com/l...     100  tt0120735
# 1                                                NaN  100017  tt0488903
# 2                                                NaN  100032  tt0099137
# 3                                                NaN  100034  tt0462634
# 4                                                NaN  100038        NaN
#
#   original_language                       original_title  ...    status  \
# 0                en  Lock, Stock and Two Smoking Barrels  ...  Released
# 1                de                             Verfolgt  ...  Released
# 2                en     The Great Los Angeles Earthquake  ...  Released
# 3                en     The Worst Horror Movie Ever Made  ...  Released
# 4                en                  Meshuggah - Nothing  ...  Released
#
#                                              tagline  \
# 0                A Disgrace to Criminals Everywhere.
# 1                                                NaN
# 2  There is no safe harbor, there is no escape......
# 3                                                NaN
# 4                                                NaN
#
#                                  title  video vote_average vote_count  \
# 0  Lock, Stock and Two Smoking Barrels  False          8.1       5798
# 1                            Punish Me  False          4.6         16
# 2     The Great Los Angeles Earthquake  False          6.9         13
# 3     The Worst Horror Movie Ever Made  False          3.0          8
# 4                  Meshuggah - Nothing  False          4.0          2
#
#    belongs_to_collection.id  belongs_to_collection.name  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#   belongs_to_collection.poster_path belongs_to_collection.backdrop_path
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
# [5 rows x 29 columns]

# %%
df_credits.head()
# Out:
#        id                                               cast  \
# 0     100  [{'adult': False, 'gender': 2, 'id': 973, 'kno...
# 1  100017  [{'adult': False, 'gender': 2, 'id': 5202, 'kn...
# 2  100032  [{'adult': False, 'gender': 1, 'id': 87038, 'k...
# 3  100034  [{'adult': False, 'gender': 0, 'id': 1022808, ...
# 4  100038                                                 []
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 960, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 2338, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 36116, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 99005, 'k...
# 4                                                 []

# %% [markdown]
# #### Three types of recommender systems
#
# 1. Demographic Filtering
# 2. Content Based Filtering
# 3. Collaborative Filtering

# %%
# join movies metadata and credits
df_movies_info = df_movies_metadata.merge(df_credits, on='id')

# %%
df_movies_info.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection   budget  \
# 0  False  /cXQH2u7wUIX1eoIdEj51kHXoWhX.jpg                    NaN  1350000
# 1  False  /cbTvuGya7E1PnL8t95AWzumjqHg.jpg                    NaN        0
# 2  False                               NaN                    NaN        0
# 3  False                               NaN                    NaN        0
# 4  False                               NaN                    NaN        0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4                   [{'id': 10402, 'name': 'Music'}]
#
#                                             homepage      id    imdb_id  \
# 0  http://www.universalstudiosentertainment.com/l...     100  tt0120735
# 1                                                NaN  100017  tt0488903
# 2                                                NaN  100032  tt0099137
# 3                                                NaN  100034  tt0462634
# 4                                                NaN  100038        NaN
#
#   original_language                       original_title  ...  \
# 0                en  Lock, Stock and Two Smoking Barrels  ...
# 1                de                             Verfolgt  ...
# 2                en     The Great Los Angeles Earthquake  ...
# 3                en     The Worst Horror Movie Ever Made  ...
# 4                en                  Meshuggah - Nothing  ...
#
#                                  title  video vote_average vote_count  \
# 0  Lock, Stock and Two Smoking Barrels  False          8.1       5798
# 1                            Punish Me  False          4.6         16
# 2     The Great Los Angeles Earthquake  False          6.9         13
# 3     The Worst Horror Movie Ever Made  False          3.0          8
# 4                  Meshuggah - Nothing  False          4.0          2
#
#   belongs_to_collection.id belongs_to_collection.name  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
#
#    belongs_to_collection.poster_path  belongs_to_collection.backdrop_path  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 2, 'id': 973, 'kno...
# 1  [{'adult': False, 'gender': 2, 'id': 5202, 'kn...
# 2  [{'adult': False, 'gender': 1, 'id': 87038, 'k...
# 3  [{'adult': False, 'gender': 0, 'id': 1022808, ...
# 4                                                 []
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 960, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 2338, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 36116, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 99005, 'k...
# 4                                                 []
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Demographic Filtering

# %% [markdown]
# Steps:
#
# 1. We require a metric to score or rate a movie.
# 2. Calculate the score for every movie.
# 3. Sort the scores and recommend the best rated movie to the users.

# %% [markdown]
# The average rating would be an obvious choice but this is not a fair score to use since a movie with a 9.3 average rating with 3 voters should not be considered better than a a movie with 8.8 average rating with 40 voters. I will use IMDB's weighted rating which is given as:

# %% [markdown]
# Weighted Rating (WR) = $(\frac{v}{v + m} \cdot R) + (\frac{m}{v + m} \cdot C)$ where,
#
# - v is the number of votes for the movie,
# - m is the minimum votes required to be listen the chart,
# - R is the average rating of the movie, and
# - C is the mean vote across the whole report

# %%
df_movies_info.head()
# Out:
#    adult                     backdrop_path  belongs_to_collection   budget  \
# 0  False  /cXQH2u7wUIX1eoIdEj51kHXoWhX.jpg                    NaN  1350000
# 1  False  /cbTvuGya7E1PnL8t95AWzumjqHg.jpg                    NaN        0
# 2  False                               NaN                    NaN        0
# 3  False                               NaN                    NaN        0
# 4  False                               NaN                    NaN        0
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 3  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 4                   [{'id': 10402, 'name': 'Music'}]
#
#                                             homepage      id    imdb_id  \
# 0  http://www.universalstudiosentertainment.com/l...     100  tt0120735
# 1                                                NaN  100017  tt0488903
# 2                                                NaN  100032  tt0099137
# 3                                                NaN  100034  tt0462634
# 4                                                NaN  100038        NaN
#
#   original_language                       original_title  ...  \
# 0                en  Lock, Stock and Two Smoking Barrels  ...
# 1                de                             Verfolgt  ...
# 2                en     The Great Los Angeles Earthquake  ...
# 3                en     The Worst Horror Movie Ever Made  ...
# 4                en                  Meshuggah - Nothing  ...
#
#                                  title  video vote_average vote_count  \
# 0  Lock, Stock and Two Smoking Barrels  False          8.1       5798
# 1                            Punish Me  False          4.6         16
# 2     The Great Los Angeles Earthquake  False          6.9         13
# 3     The Worst Horror Movie Ever Made  False          3.0          8
# 4                  Meshuggah - Nothing  False          4.0          2
#
#   belongs_to_collection.id belongs_to_collection.name  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
#
#    belongs_to_collection.poster_path  belongs_to_collection.backdrop_path  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#                                                 cast  \
# 0  [{'adult': False, 'gender': 2, 'id': 973, 'kno...
# 1  [{'adult': False, 'gender': 2, 'id': 5202, 'kn...
# 2  [{'adult': False, 'gender': 1, 'id': 87038, 'k...
# 3  [{'adult': False, 'gender': 0, 'id': 1022808, ...
# 4                                                 []
#
#                                                 crew
# 0  [{'adult': False, 'gender': 2, 'id': 960, 'kno...
# 1  [{'adult': False, 'gender': 1, 'id': 2338, 'kn...
# 2  [{'adult': False, 'gender': 2, 'id': 36116, 'k...
# 3  [{'adult': False, 'gender': 2, 'id': 99005, 'k...
# 4                                                 []
#
# [5 rows x 31 columns]

# %%
# determine m
m = df_movies_info['vote_count'].quantile(0.9)
m
# Out:
# 75.0

# %%
# calculate C
C = df_movies_info['vote_average'].mean()
C
# Out:
# 4.7209208757213394

# %%
# filter dataset to exclude movies with less than m votes
df_movies_info_filtered = df_movies_info[df_movies_info['vote_count'] >= m]

# %%
len(df_movies_info_filtered) / len(df_movies_info)
# Out:
# 0.10054137664346481

# %%
# function to calculate weighted rating
def calculate_weigted_rating(x, m=m, C=C):
    R = x['vote_average']
    v = x['vote_count']
    result = ((v/(v+m)*R)) + ((m/(v+m))*C)
    return result

# %%
# create new column for weighted rating
df_movies_info_filtered['weighted_rating'] = df_movies_info_filtered.apply(
    calculate_weigted_rating, axis=1)
# Out:
# C:\Users\Dante\AppData\Local\Temp\ipykernel_7996\2127905306.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies_info_filtered['weighted_rating'] = df_movies_info_filtered.apply(

# %%
# manuall check some values to ensure function worked correctly
df_movies_info_filtered[['vote_average',
                         'vote_count', 'weighted_rating']].head()
# Out:
#     vote_average  vote_count  weighted_rating
# 0          8.100        5798         8.056848
# 6          5.538        2795         5.516648
# 8          6.600         124         5.891804
# 28         5.100          90         4.927691
# 38         6.600         123         5.888228

# %%
# look at top 25 movies
df_movies_info_filtered[['title', 'vote_average',
                         'vote_count', 'weighted_rating']].head(25)
# Out:
#                                    title  vote_average  vote_count  \
# 0    Lock, Stock and Two Smoking Barrels         8.100        5798
# 6                     Dumb and Dumber To         5.538        2795
# 8               The Giant Mechanical Man         6.600         124
# 28                    Outpost: Black Sun         5.100          90
# 38                   Gertie the Dinosaur         6.600         123
# 83                           Lola Versus         4.900         116
# 101               Léon: The Professional         8.319       12924
# 114                   The Butterfly Room         6.000         108
# 132      The Hunger Games: Catching Fire         7.422       15559
# 182                     Mulholland Drive         7.800        5276
# 211                          Open Hearts         6.800          83
# 241                        Adam's Apples         7.500         569
# 246                   Heavenly Creatures         7.000         766
# 299                              Ant-Man         7.082       17917
# 312                            Headwinds         5.783         106
# 314                          Taxi Driver         8.200       10318
# 333                                  Olé         4.000         283
# 348                          Vicky Donor         6.800         141
# 351               Superman vs. The Elite         6.900         327
# 362                          Holy Motors         7.000         986
# 402                             The Hunt         8.093        3453
# 412                                  Mud         7.000        2461
# 416                   In Another Country         6.200          93
# 451                         Run Lola Run         7.300        1860
# 452                          The Leopard         7.700         653
#
#      weighted_rating
# 0           8.056848
# 6           5.516648
# 8           5.891804
# 28          4.927691
# 38          5.888228
# 83          4.829681
# 101         8.298240
# 114         5.475787
# 132         7.409042
# 182         7.756843
# 211         5.813095
# 241         7.176349
# 246         6.796753
# 299         7.072158
# 312         5.342912
# 314         8.174894
# 333         4.151031
# 348         6.078098
# 351         6.493455
# 362         6.838896
# 402         8.021315
# 412         6.932598
# 416         5.539697
# 451         7.200036
# 452         7.393089
